# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set(style="whitegrid")

# %% [markdown]
# Load Dataset

# %%
df = pd.read_csv("Restaurant.csv")

df.head()
# Out:
#    Restaurant_id               Name Country    City Rating     Rating_count  \
# 0         567335     AB FOODS POINT   India  Abohar     --  Too Few Ratings
# 1         531342  Janta Sweet House   India  Abohar    4.4      50+ ratings
# 2         158203  theka coffee desi   India  Abohar    3.8     100+ ratings
# 3         187912          Singh Hut   India  Abohar    3.7      20+ ratings
# 4         543530      GRILL MASTERS   India  Abohar     --  Too Few Ratings
#
#                       Cuisine
# 0            Beverages,Pizzas
# 1               Sweets,Bakery
# 2                   Beverages
# 3            Fast Food,Indian
# 4  Italian-American,Fast Food

# %% [markdown]
# Dataset Overview

# %%
df.shape        # total rows & columns
# Out:
# (148454, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148454 entries, 0 to 148453
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Restaurant_id  148454 non-null  int64
#  1   Name           148454 non-null  object
#  2   Country        148454 non-null  object
#  3   City           148454 non-null  object
#  4   Rating         148454 non-null  object
#  5   Rating_count   148454 non-null  object
#  6   Cuisine        148454 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 7.9+ MB

# %%
df.columns
# Out:
# Index(['Restaurant_id', 'Name', 'Country', 'City', 'Rating', 'Rating_count',
#        'Cuisine'],
#       dtype='object')

# %% [markdown]
# Statistical Summary

# %%
df.describe()
# Out:
#        Restaurant_id
# count  148454.000000
# mean   363505.455171
# std    167881.655190
# min       211.000000
# 25%    233516.500000
# 50%    412697.000000
# 75%    502245.500000
# max    581031.000000

# %% [markdown]
# Missing Values

# %%
df.isnull().sum()
# Out:
# Restaurant_id    0
# Name             0
# Country          0
# City             0
# Rating           0
# Rating_count     0
# Cuisine          0
# dtype: int64

# %% [markdown]
# Duplicate Records

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Restaurant_id     int64
# Name             object
# Country          object
# City             object
# Rating           object
# Rating_count     object
# Cuisine          object
# dtype: object

# %% [markdown]
# Separate Numerical & Categorical Columns

# %%
num_cols = df.select_dtypes(include=np.number).columns
cat_cols = df.select_dtypes(include="object").columns

print("Numerical Columns:", num_cols)
print("Categorical Columns:", cat_cols)
# Out:
# Numerical Columns: Index(['Restaurant_id'], dtype='object')
# Categorical Columns: Index(['Name', 'Country', 'City', 'Rating', 'Rating_count', 'Cuisine'], dtype='object')

# %% [markdown]
# Univariate Analysis

# %%
for col in num_cols:
    plt.figure(figsize=(6,3))
    sns.histplot(df[col], bins=30)
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
for col in cat_cols:
    plt.figure(figsize=(8,3))
    df[col].value_counts().head(10).plot(kind="bar")
    plt.title(f"Top Categories in {col}")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# Outlier Detection

# %%
for col in num_cols:
    plt.figure(figsize=(5,2))
    sns.boxplot(x=df[col])
    plt.title(f"Outliers in {col}")
    plt.show()
